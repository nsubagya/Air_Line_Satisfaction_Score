# %%
import os
# Specify the new directory path
new_directory_path = r"C:\Users\subag\Downloads\Airline_sat"

# Change the working directory
os.chdir(new_directory_path)

# Verify the change
print("New Working Directory:", os.getcwd())
# Out:
# New Working Directory: C:\Users\subag\Downloads\Airline_sat

# %%
import pandas as pd
import numpy as np

# .csv file must be in the same folder as the python file
file_test = r"C:\Users\subag\Downloads\Airline_sat\test.csv"
file_train = r"C:\Users\subag\Downloads\Airline_sat\train.csv"

try:
    # Attempt to read the CSV file into a DataFrame
    df_test = pd.read_csv(file_test)
    df_train = pd.read_csv(file_train)
    
    # If successful, print a success message
    print('Data read into the data frame df!')
except Exception as e:
    # If unsuccessful, print an error message
    print(f'Failed to retrieve data from the Excel file. Error: {e}')
# Out:
# Data read into the data frame df!

# %%
pip install ydata-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df_train, title="Pandas Profiling Report")
profile.to_file("EDA_crime_data.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pd.set_option('display.max_columns', None)

# %%
df_train.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %%
df_train = df_train.drop(columns=['Unnamed: 0'])

# %%
df_train.shape
# Out:
# (103904, 24)

# %%
df_train.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %%
df_test.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              4
# ...

# %%
df_test = df_test.drop(columns=['Unnamed: 0'])

# %%
df_test.shape
# Out:
# (25976, 24)

# %%
df_test.isnull().sum()
# Out:
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             83
# ...

# %%
print(df_train.columns,df_test.columns)
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object') Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
# ...

# %%
#df_train['Arrival Delay in Minutes'].unique()

# %%
df_missing = df_train[df_train['Arrival Delay in Minutes'].isnull()]
df_not_missing = df_train[~df_train['Arrival Delay in Minutes'].isnull()]
df_not_missing.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
def plot_scatter(data_frame,x_value,y_value,alpha):
    plt.scatter(data_frame[x_value], data_frame[y_value], alpha=alpha)
    plt.xlabel(x_value)
    plt.ylabel(y_value)
    plt.title(f'{x_value} vs. {y_value}')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10, 6))
plot_scatter(df_not_missing,'Departure Delay in Minutes','Arrival Delay in Minutes',0.5)
# Out:
# C:\Users\subag\AppData\Local\Temp\ipykernel_30748\3542036024.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from scipy import stats

# %%
def anova_value(data_frame,x_value,y_value):
    numb_unique = data_frame[x_value].nunique()
    categories = [data_frame[data_frame[x_value] == i][y_value] for i in range(numb_unique)]
    anova_result = stats.f_oneway(*categories)
    return anova_result

# %%
#anova_value(df_not_missing,'Baggage handling','Arrival Delay in Minutes')#not sure why this is happening need attention

# %%
#df_not_missing['Baggage handling'].nunique()

# %%
not_miss_var = ['Flight Distance','Departure/Arrival time convenient','Gate location','Online boarding','Checkin service','Departure Delay in Minutes']
#not_miss_var = ['Flight Distance','Departure/Arrival time convenient','Gate location','Online boarding','Baggage handling','Checkin service','Departure Delay in Minutes','Arrival Delay in Minutes']

# %%
for mis_var in not_miss_var:
    x_value = mis_var
    y_value = 'Arrival Delay in Minutes'
    data_frame = df_not_missing
    if data_frame[x_value].nunique()<7:
        ANOVA_val = anova_value(data_frame,x_value,y_value)
        print(f'ANOVA value for {mis_var} is {ANOVA_val}')
# Out:
# ANOVA value for Departure/Arrival time convenient is F_onewayResult(statistic=5.221002247361213, pvalue=8.52578716983651e-05)
# ANOVA value for Gate location is F_onewayResult(statistic=2.3566467917492777, pvalue=0.03788919712208852)
# ANOVA value for Online boarding is F_onewayResult(statistic=39.0310821746488, pvalue=3.374796549097471e-40)
# ANOVA value for Checkin service is F_onewayResult(statistic=27.271392477832478, pvalue=1.1103135372915799e-27)

# %%
#not_miss_var.remove('Baggage handling','Arrival Delay in Minutes')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = df_not_missing[not_miss_var]
y = df_not_missing['Arrival Delay in Minutes']
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)
model = LinearRegression()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 103.77287150059293
# R-squared: 0.9315746766532781

# %%
df_missing = df_missing.copy()
df_missing['Arrival Delay in Minutes'] = model.predict(df_missing[not_miss_var]).round().astype(int)
df_missing.head()
# Out:
#           id  Gender      Customer Type  Age   Type of Travel     Class  \
# 213    49608  Female     Loyal Customer   38  Business travel       Eco
# 1124   73442    Male     Loyal Customer   53  Personal Travel       Eco
# 1529   71178    Male     Loyal Customer   39  Business travel  Business
# 2004   72940  Female  disloyal Customer   26  Business travel  Business
# 2108  116374  Female     Loyal Customer   24  Personal Travel       Eco
#
#       Flight Distance  Inflight wifi service  \
# 213               109                      5
# 1124             1012                      3
# 1529              733                      2
# 2004             1035                      3
# 2108              417                      2
#
#       Departure/Arrival time convenient  Ease of Online booking  \
# 213                                   3                       3
# 1124                                  2                       3
# ...

# %%
df_train.set_index('id', inplace=True)
df_missing.set_index('id', inplace=True)
df_train.update(df_missing[['Arrival Delay in Minutes']])
df_train.reset_index(inplace=True)

# %%
df_train.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# ...

# %%
df_train.isnull().sum().sum()
# Out:
# 0

# %%
df_test_missing = df_test[df_test['Arrival Delay in Minutes'].isnull()]
df_test_missing.head()
# Out:
#           id  Gender      Customer Type  Age   Type of Travel Class  \
# 516   107365  Female     Loyal Customer   21  Personal Travel   Eco
# 656   108648    Male     Loyal Customer    9  Personal Travel   Eco
# 1071   16797    Male  disloyal Customer   25  Business travel   Eco
# 1224   30090    Male     Loyal Customer    7  Personal Travel   Eco
# 1589   41924  Female     Loyal Customer   58  Business travel   Eco
#
#       Flight Distance  Inflight wifi service  \
# 516               632                      1
# 656               762                      2
# 1071             1017                      3
# 1224              399                      4
# 1589              129                      5
#
#       Departure/Arrival time convenient  Ease of Online booking  \
# 516                                   5                       1
# 656                                   5                       2
# 1071                                  4                       4
# ...

# %%
df_test_missing = df_test_missing.copy()
df_test_missing['Arrival Delay in Minutes'] = model.predict(df_test_missing[not_miss_var]).round().astype(int)
df_test_missing.head()
# Out:
#           id  Gender      Customer Type  Age   Type of Travel Class  \
# 516   107365  Female     Loyal Customer   21  Personal Travel   Eco
# 656   108648    Male     Loyal Customer    9  Personal Travel   Eco
# 1071   16797    Male  disloyal Customer   25  Business travel   Eco
# 1224   30090    Male     Loyal Customer    7  Personal Travel   Eco
# 1589   41924  Female     Loyal Customer   58  Business travel   Eco
#
#       Flight Distance  Inflight wifi service  \
# 516               632                      1
# 656               762                      2
# 1071             1017                      3
# 1224              399                      4
# 1589              129                      5
#
#       Departure/Arrival time convenient  Ease of Online booking  \
# 516                                   5                       1
# 656                                   5                       2
# 1071                                  4                       4
# ...

# %%
df_test.set_index('id', inplace=True)
df_test_missing.set_index('id', inplace=True)
df_test.update(df_test_missing[['Arrival Delay in Minutes']])
df_test.reset_index(inplace=True)

# %%
df_test.head()
# Out:
#       id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0  19556  Female     Loyal Customer   52  Business travel       Eco
# 1  90035  Female     Loyal Customer   36  Business travel  Business
# 2  12360    Male  disloyal Customer   20  Business travel       Eco
# 3  77959    Male     Loyal Customer   44  Business travel  Business
# 4  36875  Female     Loyal Customer   49  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              160                      5                                  4
# 1             2863                      1                                  1
# 2              192                      2                                  0
# 3             3377                      0                                  0
# 4             1182                      2                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# ...

# %%
df_test.isnull().sum().sum()
# Out:
# 0

# %%
df_test_new = df_test.copy()
df_train_new = df_train.copy()

# %%
duplicate_test = df_test_new[df_test_new['id'].duplicated(keep=False)]
duplicate_train = df_train_new[df_train_new['id'].duplicated(keep=False)] 

concatenated_df = pd.concat([df_train_new, df_test_new])
duplicate_concat = concatenated_df[concatenated_df['id'].duplicated(keep=False)]

print(duplicate_test,duplicate_train,duplicate_concat)
# Out:
# Empty DataFrame
# Columns: [id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: [] Empty DataFrame
# Columns: [id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: [] Empty DataFrame
# ...

# %%
def obj_to_int(data_frame):
    for col in data_frame.columns:
        if data_frame[col].dtype == 'object':
            unique_val = data_frame[col].unique()
            temp_map = {}
            for index, val in enumerate(unique_val):
                temp_map[val] = index
            data_frame[col] = data_frame[col].replace(temp_map)
            print(col,temp_map)

# %%
obj_to_int(concatenated_df)
# Out:
# Gender {'Male': 0, 'Female': 1}
# Customer Type {'Loyal Customer': 0, 'disloyal Customer': 1}
# Type of Travel {'Personal Travel': 0, 'Business travel': 1}
# Class {'Eco Plus': 0, 'Business': 1, 'Eco': 2}
# satisfaction {'neutral or dissatisfied': 0, 'satisfied': 1}

# %%
df_train_new = concatenated_df[concatenated_df['id'].isin(df_train['id'])]
df_test_new = concatenated_df[concatenated_df['id'].isin(df_test['id'])]

# %%
for mis_var in df_train_new.columns:
    x_value = mis_var
    y_value = 'satisfaction'
    data_frame = df_train_new
    if data_frame[x_value].nunique()<7:
        ANOVA_val = anova_value(data_frame,x_value,y_value)
        print(f'ANOVA value for {mis_var} is {ANOVA_val}')
# Out:
# ANOVA value for Gender is F_onewayResult(statistic=15.495681282193619, pvalue=8.274779839697538e-05)
# ANOVA value for Customer Type is F_onewayResult(statistic=3791.6883583474487, pvalue=0.0)
# ANOVA value for Type of Travel is F_onewayResult(statistic=26236.004394474192, pvalue=0.0)
# ANOVA value for Class is F_onewayResult(statistic=17760.410188756727, pvalue=0.0)
# ANOVA value for Inflight wifi service is F_onewayResult(statistic=7928.719681675326, pvalue=0.0)
# ANOVA value for Departure/Arrival time convenient is F_onewayResult(statistic=90.6006286966675, pvalue=1.7966676366298476e-95)
# ANOVA value for Ease of Online booking is F_onewayResult(statistic=2313.0933863291466, pvalue=0.0)
# ANOVA value for Gate location is F_onewayResult(statistic=510.9207904759094, pvalue=0.0)
# ANOVA value for Food and drink is F_onewayResult(statistic=1095.4439912248713, pvalue=0.0)
# ANOVA value for Online boarding is F_onewayResult(statistic=12875.621274976307, pvalue=0.0)
# ...

# %%
'''
temp_var = ['Departure/Arrival time convenient','Food and drink', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
        'Checkin service', 'Inflight service',
       'Cleanliness']
'''
# Out:
# "\ntemp_var = ['Departure/Arrival time convenient','Food and drink', 'Seat comfort',\n       'Inflight entertainment', 'On-board service', 'Leg room service',\n        'Checkin service', 'Inflight service',\n       'Cleanliness']\n"

# %%
temp_var = ['Customer Type', 'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service', 
            'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 
            'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Checkin service', 'Inflight service', 
            'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %%
from sklearn import linear_model
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
#logreg = LogisticRegression()
#logreg.fit(X_train, y_train)


#y_pred = logreg.predict(X_test)
#y_pred_proba = logreg.predict_proba(X_test)[:, 1]


#accuracy = accuracy_score(y_test, y_pred)
#auc = roc_auc_score(y_test, y_pred_proba)

# %%
def auc(variables, target, basetable):
    X = basetable[variables]
    y = basetable[target].values.ravel()
    logreg = RandomForestClassifier(n_estimators=10, random_state=10)
    logreg.fit(X, y)
    predictions = logreg.predict_proba(X)[:,1]
    auc = roc_auc_score(y, predictions)
    return(auc)

# %%
def next_best(current_variables,candidate_variables, target, basetable):
    best_auc = -1
    best_variable = None
    for v in candidate_variables:
        auc_v = auc(current_variables + [v], target, basetable)
    if auc_v >= best_auc:
        best_auc = auc_v
        best_variable = v
    return best_variable

# %%
candidate_variables = temp_var
current_variables = []
target = ["satisfaction"]
max_number_variables = 10
number_iterations = min(max_number_variables, len(candidate_variables))
for i in range(0,number_iterations):
    next_variable = next_best(current_variables,candidate_variables,target,df_train_new)
    current_variables.append(next_variable)
    candidate_variables.remove(next_variable)
print(current_variables)
# Out:
# ['Arrival Delay in Minutes', 'Departure Delay in Minutes', 'Cleanliness', 'Inflight service', 'Checkin service', 'Leg room service', 'On-board service', 'Inflight entertainment', 'Seat comfort', 'Online boarding']

# %%
X = df_train_new[current_variables]
y = df_train_new['satisfaction']
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

model = RandomForestClassifier(n_estimators=10, random_state=10)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

#mse = mean_squared_error(y_test, y_pred)
#r2 = r2_score(y_test, y_pred)

accuracy = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)

#print(f"Mean Squared Error: {mse}")
#print(f"R-squared: {r2}")
print(f"Accuracy: {accuracy}")
print(f"AUC Score: {auc}")
# Out:
# Accuracy: 0.8696405370290169
# AUC Score: 0.9314447528921024

# %%
df_test_new = df_test_new.copy()
df_test_new['satisfaction'] = model.predict(df_test_new[current_variables]).round().astype(int)
df_test_new.head()
# Out:
#       id  Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0  19556       1              0   52               1      2              160
# 1  90035       1              0   36               1      1             2863
# 2  12360       0              1   20               1      2              192
# 3  77959       0              0   44               1      1             3377
# 4  36875       1              0   49               1      2             1182
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# ...

# %%
for i in range(df_test['Gender'].nunique()):
    print(i)
# Out:
# 0
# 1

# %%
#!pip install sqlalchemy

# %%
#%load_ext sql
#import csv, sqlite3
#con = sqlite3.connect("my_data1.db")
#%sql sqlite:///my_data1.db
#df_train.to_sql("SPACEXTBL", con, if_exists='replace', index=False)

# %%
#%%sql 
#SELECT DISTINCT "Customer Type" FROM SPACEXTBL

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 25976 non-null  int64
#  1   Gender                             25976 non-null  object
#  2   Customer Type                      25976 non-null  object
#  3   Age                                25976 non-null  int64
#  4   Type of Travel                     25976 non-null  object
#  5   Class                              25976 non-null  object
#  6   Flight Distance                    25976 non-null  int64
#  7   Inflight wifi service              25976 non-null  int64
#  8   Departure/Arrival time convenient  25976 non-null  int64
#  9   Ease of Online booking             25976 non-null  int64
#  10  Gate location                      25976 non-null  int64
# ...

# %%
model
# Out:
# RandomForestClassifier(n_estimators=10, random_state=10)

# %%
import joblib

# %%
# Save the model
joblib.dump(model, "Air_line_model.pkl")
# Out:
# ['Air_line__model.pkl']
